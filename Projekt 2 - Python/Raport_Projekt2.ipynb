# %%
import plot_mod as gm

# %% [markdown]
# ## *GREEN ENERGY*

# %%
gm.udzial_green_UE()

# %% [markdown]
# ###  The percentage share of green energy in the total production of European countries has been increasing since 2010. We can divide countries into 3 segments with high, medium and low green energy production. These segments maintain a different dynamics over the years. The best segment had a downward trend until 2010. The medium segment maintained a steady share of green energy until 2005. Then they will start growing. The last weakest segment had a minimum steady share of green energy until 2010.

# %%
gm.max_min_avg_green_UE()

# %% [markdown]
# ### We notice a big difference between the countries with the highest share of green energy and the countries with the lowest share. This difference does not decrease in the following years. The average is closer to the minimum than the maximum, which proves the presence of clear leaders.

# %%
gm.green_top10_plot()

# %% [markdown]
# ### Analyzing the top 10 countries. Two of them are worth paying attention to. Luxembourg, which after 2000 reduced the share of green energy by 50% over 2 years. The second country is Lithuania, which has recorded the greatest exemplary results after 2009 and reduces the difference compared to the leaders.

# %% [markdown]
# ## Select a country and the green category for a deeper analysis

# %%
gm.widgets_interact()
gm.plot_total()
gm.plot_category()
gm.plot_bar_100() #opcja 2
# Out:
# interactive(children=(Dropdown(description='country_choice', options=('Austria', 'Belgium', 'Bulgaria', 'Denma…
# Description of the energy source:
# Geothermal energy is heat derived within the sub-surface of the earth. Water and/or steam carry the geothermal energy to the Earth's surface. Depending on its characteristics, geothermal energy can be used for heating and cooling purposes or be harnessed to generate clean electricity.

# %% [markdown]
# # *HEAT ENERGY*

# %%
gm.udzial_heat_UE()

# %% [markdown]
# ### All European countries have more than 50% of dirty energy. After 2010, a downward trend is noticeable. This trend is the greatest for countries with a dirty energy share of 70-90%. Countries that have nearly 100% of dirty energy, unfortunately, convert more slowly to other energy sources. Two countries behave unexpectedly. In 2000, a very large increase in the production of dirty energy was recorded in Luxembourg. We see a similar situation in 2009 in Lithuania.

# %%
gm.max_min_avg_heat_UE()

# %% [markdown]
# ### In addition to dirty energy. We also see a big difference between the countries with the largest and smallest shares. The average is closer to the high, which suggests that most countries, however, produce a lot of dirty energy.

# %%
gm.heat_top10_UE_plot()

# %% [markdown]
# ### The top 10 chart confirms the earlier observation that countries with the highest share of dirty energy convert to green energy at a slow pace. Italy, Ireland and the Netherlands have the best conversion rates in this group.

# %% [markdown]
# ## Select a country to compare with TOP5 HEAT

# %%
gm.widget_heat()
gm.plot_total_heat()
# Out:
# interactive(children=(Dropdown(description='country_choice_heat', options=('Austria', 'Belgium', 'Bulgaria', '…

# %% [markdown]
# # *NUCLEAR ENERGY*

# %%
gm.udział_nuclear_UE()

# %% [markdown]
# ### The share of nuclear energy in individual countries is stable. This may indicate the lack of investment in this type of energy, and the maintenance of current sources. Only Lithuania completely abandoned nuclear energy production in 2009. Closing its only nuclear power plant, Ignalińska.

# %%
gm.max_min_avg_nuclear_UE()

# %% [markdown]
# ### The graph of the mean, max and min show a constant value over the years. You can see from the chart that there are a few leaders in nuclear energy production.

# %%
gm.nuclear_top10_plot()

# %% [markdown]
# ### TOP 10 also unchanged over the years. The leader is France.

# %% [markdown]
# ## Select a country to compare with TOP5 NUCLEAR

# %%
gm.widget_nuc()
gm.plot_total_nuc()
# Out:
# interactive(children=(Dropdown(description='country_choice_nuc', options=('Belgium', 'Bulgaria', 'Finland', 'F…
# Nuclear power is the use of nuclear reactions that release nuclear energy to generate heat, which most frequently is then used in steam turbines to produce electricity in a nuclear power plant. Nuclear power can be obtained from nuclear fission, nuclear decay and nuclear fusion reactions.
